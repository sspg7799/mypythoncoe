# %%
# #error 3 type 

# 1) compile time error (syntax error ())
# 2) logical error
# 3) run time error

# %%
print("hello shiva"  # syntax error or compile time erroe
# Out:
#   Input In [2]
#     print("hello shiva"
#                        ^
# SyntaxError: unexpected EOF while parsing

# %%
#logical error 

a=10
b=20  
c=a-b  # we should change substraction  (-) to  addition (+)
# logical erros nothing but....we only made the mistake while writting the logic 
print("sum=",c)   logical error
# Out:
# sum= -10

# %%
#run time errors   or exceoptions  

a=int(input("enter a values"))
b=int(input("enter a values"))
print(a/b)     # try block lo rasthamu elanti situations lo
# Out:
# enter a values20
# enter a values0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [6], in <cell line: 5>()
#       3 a=int(input("enter a values"))
#       4 b=int(input("enter a values"))
# ----> 5 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
# 1) try block  # division by zero   in 
# 2) except block
# 3) else block
# 4) finally block

# %% [markdown]
# ![errors.png](attachment:errors.png)

# %%
#attribute error
class demo:
    a=20
    
obj= demo()
obj.b    # b values not avilable in class ..to over come this error...use try block .....check below example
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 6>()
#       3     a=20
#       5 obj= demo()
# ----> 6 obj.b
#
# AttributeError: 'demo' object has no attribute 'b'

# %%
class demo:
    a=10
try:
    obj= demo()
    obj.b
except Exception as e:
    print(e)
# Out:
# 'demo' object has no attribute 'b'

# %%
#method 2:

class demo:
    a=10
try:
    obj= demo()
    obj.b
except:
    print("access number not part of class")
# Out:
# access number not part of class

# %%
#filenotfound error

file=open("mym.txt","r")

content=file.read()
print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [35], in <cell line: 3>()
#       1 #filenotfound error
# ----> 3 file=open("mym.txt","r")
#       5 content=file.read()
#       6 print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mym.txt'

# %%
#filenotfound error
try:
    file=open("mym.txt","r")
    content=file.read()
    print(content)

except:
    print(" file not avilable in source location")
# Out:
#  file not avilable in source location

# %%
#index error

list1=[10,20,30,40,50]  #indesx   starts with  0 1 2 3 4 5
for x in range(6):
    print(list1[x])
# Out:
# 10
# 20
# 30
# 40
# 50
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [50], in <cell line: 4>()
#       3 list1=[10,20,30,40,50]  #indesx   starts with  0 1 2 3 4 5
#       4 for x in range(6):
# ----> 5     print(list1[x])
#
# IndexError: list index out of range

# %%
# key error
dic={"shiva":30 , "jani":"31"}
print(dic["prasad"])   #   prasad not avaible in dictionary
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [59], in <cell line: 3>()
#       1 # key error
#       2 dic={"shiva":30 , "jani":"31"}
# ----> 3 print(dic["prasad"])
#
# KeyError: 'prasad'

# %%
# key error
try:
    dic={"shiva":30 , "jani":"31"}
    print(dic["prasad"])
              
except:
    print("prasad not in dictinary")
# Out:
# prasad not in dictinary

# %%
#name error
f=10
g=20
print(f,g,j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 3>()
#       1 f=10
#       2 g=20
# ----> 3 print(f,g,j)
#
# NameError: name 'j' is not defined

# %%
#type error
# Out:
# 5.0
# 30
# no exceptions
# code executed

# %%
#value error

a="hello"
p=int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [63], in <cell line: 4>()
#       1 #type error
#       3 a="hello"
# ----> 4 p=int(a)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
#zero divison error

a=int(input("a value"))
b=int(input("b value"))
print(a/b)
# Out:
# a value10
# b value0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [67], in <cell line: 5>()
#       3 a=int(input("a value"))
#       4 b=int(input("b value"))
# ----> 5 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
#zero divison error
try:
    t1=[10,20,30]
    print(10/0
         )
    print(t1[5])
    
except Exception as e:
    print(e)
else:
    print("no exceptions")
finally:
    print("code executed")
# Out:
# division by zero
# code executed

# %%
#type error

a=50+"shell"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [81], in <cell line: 3>()
#       1 #type error
# ----> 3 a=50+"shell"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
